# %% [markdown]
# Loading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/work/chennai_house_price_prediction.csv') #load the dataset into data frame

# %%
df.shape # check  the size of the dataset
# Out:
# (7109, 19)

# %%
df.head()  #check for few rows data matching for column count
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
# ...

# %% [markdown]
# Data Exploration

# %%
df.describe() # create a summury using describe function gives only continous variables data
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL         COMMIS  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  141005.726544
# std       0.891972     0.897834     0.887266     0.527223   78768.093718
# ...

# %%
df.describe(include='all') #describe the summry with continous and catagorical values
# Out:
#         PRT_ID      AREA     INT_SQFT  DIST_MAINROAD    N_BEDROOM  \
# count     7109      7109  7109.000000    7109.000000  7108.000000
# unique    7109        17          NaN            NaN          NaN
# top     P04991  Chrompet          NaN            NaN          NaN
# freq         1      1681          NaN            NaN          NaN
# mean       NaN       NaN  1382.073006      99.603179     1.637029
# std        NaN       NaN   457.410902      57.403110     0.802902
# min        NaN       NaN   500.000000       0.000000     1.000000
# 25%        NaN       NaN   993.000000      50.000000     1.000000
# 50%        NaN       NaN  1373.000000      99.000000     1.000000
# 75%        NaN       NaN  1744.000000     148.000000     2.000000
# max        NaN       NaN  2500.000000     200.000000     4.000000
#
#          N_BATHROOM       N_ROOM SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL  \
# count   7104.000000  7109.000000      7109       7109      7109          7109
# ...

# %% [markdown]
# Isnull function

# %%
df.isnull() # this function gives the missing values in the data
# Out:
#       PRT_ID   AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0      False  False     False          False      False       False   False
# 1      False  False     False          False      False       False   False
# 2      False  False     False          False      False       False   False
# 3      False  False     False          False      False       False   False
# 4      False  False     False          False      False       False   False
# ...      ...    ...       ...            ...        ...         ...     ...
# 7104   False  False     False          False      False       False   False
# 7105   False  False     False          False      False       False   False
# 7106   False  False     False          False      False       False   False
# 7107   False  False     False          False      False       False   False
# 7108   False  False     False          False      False       False   False
#
# ...

# %%
df.isnull().sum() # gives the counts of missing values
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %% [markdown]
# Data Types

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
temp=pd.DataFrame(index=df.columns)
temp['data_type']=df.dtypes
temp['null_count']=df.isnull().sum()
temp['unique_count']=df.nunique()

# %%
temp #created a temporary table to get clear deatils
# Out:
#               data_type  null_count  unique_count
# PRT_ID           object           0          7109
# AREA             object           0            17
# INT_SQFT          int64           0          1699
# DIST_MAINROAD     int64           0           201
# N_BEDROOM       float64           1             4
# N_BATHROOM      float64           5             2
# N_ROOM            int64           0             5
# SALE_COND        object           0             9
# PARK_FACIL       object           0             3
# BUILDTYPE        object           0             5
# UTILITY_AVAIL    object           0             5
# STREET           object           0             5
# MZZONE           object           0             6
# QS_ROOMS        float64           0            31
# QS_BATHROOM     float64           0            31
# QS_BEDROOM      float64           0            31
# QS_OVERALL      float64          48           479
# COMMIS            int64           0          7011
# ...

# %%
df['N_BEDROOM'] #bedrooms are in float type it has to  be converted while manupulating
# Out:
# 0       1.0
# 1       2.0
# 2       1.0
# 3       3.0
# 4       1.0
#        ...
# 7104    1.0
# 7105    3.0
# 7106    2.0
# 7107    1.0
# 7108    3.0
# Name: N_BEDROOM, Length: 7109, dtype: float64

# %% [markdown]
# Univariate analysis

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'BUILDTYPE',
#        'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS', 'QS_BATHROOM',
#        'QS_BEDROOM', 'QS_OVERALL', 'COMMIS', 'SALES_PRICE'],
#       dtype='object')

# %%
# Target variable

df['SALES_PRICE'].plot.hist(bins=50)
plt.xlabel('SALES',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-7fb7a8187feb> in <module>
#       2
#       3 df['SALES_PRICE'].plot.hist(bins=50)
# ----> 4 plt.xlabel('SALES',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %% [markdown]
# since the plot shows it ir right skewed few houses are costing more so using loc function will check the plot

# %%
df['SALES_PRICE'].loc[df['SALES_PRICE']<18000000].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## area of house in square feet

df['INT_SQFT'].plot.hist(bins=50) # right skewed only few houses with more than 2000 sqft
plt.xlabel('Area in Sqft',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-dc46ef24b17a> in <module>
#       2
#       3 df['INT_SQFT'].plot.hist(bins=50) # right skewed only few houses with more than 2000 sqft
# ----> 4 plt.xlabel('Area in Sqft',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
# ...

# %%
df['INT_SQFT'].loc[df['INT_SQFT']<2000].plot.hist(bins=50)
plt.xlabel('Area in Sqft',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4f51fe9ede02> in <module>
#       1 df['INT_SQFT'].loc[df['INT_SQFT']<2000].plot.hist(bins=50)
# ----> 2 plt.xlabel('Area in Sqft',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %%
df['COMMIS'].plot.hist(bins=50)
plt.xlabel('COMMIS',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-dc3c875378db> in <module>
#       1 df['COMMIS'].plot.hist(bins=50)
# ----> 2 plt.xlabel('COMMIS',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %%
df['COMMIS'].loc[df['COMMIS']<300000].plot.hist(bins=50)
plt.xlabel('COMMIS',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-a8bd6d52470b> in <module>
#       1 df['COMMIS'].loc[df['COMMIS']<300000].plot.hist(bins=50)
# ----> 2 plt.xlabel('COMMIS',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %%
df['DIST_MAINROAD'].plot.hist(bins=50)
plt.xlabel('Distance from mainroad',fontdict=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-607c2ca9b40a> in <module>
#       1 df['DIST_MAINROAD'].plot.hist(bins=50)
# ----> 2 plt.xlabel('Distance from mainroad',fontdict=15)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
# -> 3117         **kwargs)
#    3118
#    3119
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %% [markdown]
# Value counts

# %%
df['N_BEDROOM'].value_counts()
# Out:
# 1.0    3795
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64

# %%
df['N_BEDROOM'].value_counts()/len(df)*100
# Out:
# 1.0    53.383036
# 2.0    33.084822
# 3.0     9.945140
# 4.0     3.572936
# Name: N_BEDROOM, dtype: float64

# %%
df['N_ROOM'].value_counts()
# Out:
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64

# %%
df['N_ROOM'].value_counts()/len(df)*100
# Out:
# 4    36.052891
# 3    29.891687
# 5    17.527078
# 2    12.955409
# 6     3.572936
# Name: N_ROOM, dtype: float64

# %%
df['N_BATHROOM'].value_counts()
# Out:
# 1.0    5589
# 2.0    1515
# Name: N_BATHROOM, dtype: int64

# %%
df['N_BATHROOM'].value_counts()/len(df)*100
# Out:
# 1.0    78.618652
# 2.0    21.311014
# Name: N_BATHROOM, dtype: float64

# %% [markdown]
# BAR plot

# %%
df['N_BATHROOM'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['AREA'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#house with parking lot

df['PARK_FACIL'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
